# %% [markdown]
# # MGNREGA DATA ANALYSIS

# %% [markdown]
# ## This dataset provides detailed insights into the implementation of the **Mahatma Gandhi National Rural Employment Guarantee Act (MGNREGA)** across various Indian states and districts from 2014 to 2022. It captures critical parameters such as:
#
# - Number of job cards issued
# - Households demanding and allotted work
# - Person-days of employment generated (including gender-wise split)
# - Financial disbursements (via banks and post offices)
# - Participation of SC/ST communities
# - District and state-level summaries
#
# The dataset enables a deep dive into rural employment patterns, gaps in work allocation, and fund distribution efficiency — making it a powerful tool for both data-driven governance and academic exploration.

# %% [markdown]
# LOADING DATSET

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
df=pd.read_csv("C:\\Users\\ASUS\\Desktop\\DATASETS\\knndap.niti.gov (2).csv")
df.head()
# Out:
#    srcYear srcStateName      srcDistrictName  \
# 0  2011-12  WEST BENGAL           COOCHBEHAR
# 1  2011-12  WEST BENGAL              BIRBHUM
# 2  2011-12  WEST BENGAL              BANKURA
# 3  2011-12  WEST BENGAL    24 PARGANAS SOUTH
# 4  2011-12  WEST BENGAL  24 PARGANAS (NORTH)
#
#    Households that applied for a Job Card  Job Cards issued  \
# 0                                  602112            602043
# 1                                  658227            658163
# 2                                  579173            579049
# 3                                  822194            822020
# 4                                  741737            741584
#
#    Job Cards issued for Scheduled Caste  \
# 0                                317446
# 1                                221090
# 2                                231214
# 3                                181933
# 4                                223175
#
#    Job Cards issued for Scheduled Tribes  \
# 0                                   5923
# 1                                  51506
# 2                                  70983
# 3                                   5907
# 4                                  33798
#
#    Job Cards issued for non Scheduled Tribes or Scheduled Caste  \
# 0                                             278674
# 1                                             385567
# 2                                             276852
# 3                                             634180
# 4                                             484611
#
#    Households that demanded work  Persons who demanded work  ...  \
# 0                         298510                     330033  ...
# 1                         469323                     747447  ...
# 2                         327474                     654422  ...
# 3                         197023                     281701  ...
# 4                         339623                     470852  ...
#
#    Total bank accounts  Individual bank accounts  Joint bank accounts  \
# 0               105235                     94052                11183
# 1               181900                    115403                66497
# 2                83145                     52872                30273
# 3                66080                     56409                 9671
# 4               228612                    171563                57049
#
#    Amount disbursed to bank accounts  Post office accounts  \
# 0                          125943230                255797
# 1                          650354141                469576
# 2                          206025728                228346
# 3                          138370561                108978
# 4                          610591153                342725
#
#    Individual post office accounts  Joint post office accounts  \
# 0                           225556                       30241
# 1                           347648                      121928
# 2                           136710                       91636
# 3                            82659                       26319
# 4                           259657                       83068
#
#    Amount disbursed to post office accounts                              Year  \
# 0                                 311088943  Financial Year (Apr - Mar), 2011
# 1                                1470018793  Financial Year (Apr - Mar), 2011
# 2                                 563641705  Financial Year (Apr - Mar), 2011
# 3                                 257047048  Financial Year (Apr - Mar), 2011
# 4                                 842944905  Financial Year (Apr - Mar), 2011
#
#    YearCode
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
#
# [5 rows x 44 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 44 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   srcYear                                                                                        6368 non-null   object
#  1   srcStateName                                                                                   6368 non-null   object
#  2   srcDistrictName                                                                                6368 non-null   object
#  3   Households that applied for a Job Card                                                         6368 non-null   int64
#  4   Job Cards issued                                                                               6368 non-null   int64
#  5   Job Cards issued for Scheduled Caste                                                           6368 non-null   int64
#  6   Job Cards issued for Scheduled Tribes                                                          6368 non-null   int64
#  7   Job Cards issued for non Scheduled Tribes or Scheduled Caste                                   6368 non-null   int64
#  8   Households that demanded work                                                                  6368 non-null   int64
#  9   Persons who demanded work                                                                      6368 non-null   int64
#  10  Households that were allotted work                                                             6368 non-null   int64
#  11  Persons that were allotted work                                                                6368 non-null   int64
#  12  Muster Rolls filled                                                                            6368 non-null   int64
#  13  Households that worked under Mahatma Gandhi National Rural Employment Guarantee Act (MGNREGA)  6368 non-null   int64
#  14  Persons that worked under Mahatma Gandhi National Rural Employment Guarantee Act (MGNREGA)     6368 non-null   int64
#  15  Households that reached a 100 day limit                                                        6368 non-null   int64
#  16  Persons with disability                                                                        6368 non-null   int64
#  17  Non Scheduled Tribes or Scheduled Caste households that worked                                 6368 non-null   int64
#  18  Total Person days worked by non Scheduled Tribes or Scheduled Caste persons                    6368 non-null   int64
#  19  Scheduled Caste households that worked                                                         6368 non-null   int64
#  20  Total Person days worked Scheduled Caste persons                                               6368 non-null   int64
#  21  Scheduled Tribe households that worked                                                         6368 non-null   int64
#  22  Total Person days worked Scheduled Tribe persons                                               6368 non-null   int64
#  23  Households that worked on land reform or Indira Awas Yojana                                    6368 non-null   int64
#  24  Total Person days worked by women                                                              6368 non-null   int64
#  25  Total Person days                                                                              6368 non-null   int64
#  26  Scheduled Caste households that reached a 100 Day Limit                                        6368 non-null   int64
#  27  Scheduled Tribe households that reached a 100 Day Limit                                        6368 non-null   int64
#  28  Labour expenditure that has been disbursed                                                     6314 non-null   float64
#  29  Material expenditure that has been disbursed                                                   6314 non-null   float64
#  30  Labour expenditure both disbursed and pending                                                  6314 non-null   float64
#  31  Material expenditure both disbursed and pending                                                6314 non-null   float64
#  32  Amount sanctioned                                                                              6314 non-null   float64
#  33  Works under Mahatma Gandhi National Rural Employment Guarantee Act (MGNREGA)                   6314 non-null   float64
#  34  Total bank accounts                                                                            6368 non-null   int64
#  35  Individual bank accounts                                                                       6368 non-null   int64
#  36  Joint bank accounts                                                                            6368 non-null   int64
#  37  Amount disbursed to bank accounts                                                              6368 non-null   int64
#  38  Post office accounts                                                                           6368 non-null   int64
#  39  Individual post office accounts                                                                6368 non-null   int64
#  40  Joint post office accounts                                                                     6368 non-null   int64
#  41  Amount disbursed to post office accounts                                                       6368 non-null   int64
#  42  Year                                                                                           6368 non-null   object
#  43  YearCode                                                                                       6368 non-null   int64
# dtypes: float64(6), int64(34), object(4)
# memory usage: 2.1+ MB
#        Households that applied for a Job Card  Job Cards issued  \
# count                            6.368000e+03      6.368000e+03
# mean                             2.016431e+05      1.965364e+05
# std                              1.768031e+05      1.722818e+05
# min                              0.000000e+00      0.000000e+00
# 25%                              7.566050e+04      7.370875e+04
# 50%                              1.606835e+05      1.570050e+05
# 75%                              2.668378e+05      2.599545e+05
# max                              1.495713e+06      1.284676e+06
#
#        Job Cards issued for Scheduled Caste  \
# count                           6368.000000
# mean                           41379.074592
# std                            50846.652306
# min                                0.000000
# 25%                             8092.250000
# 50%                            25098.000000
# 75%                            54892.250000
# max                           418915.000000
#
#        Job Cards issued for Scheduled Tribes  \
# count                            6368.000000
# mean                            25817.195666
# std                             41122.073623
# min                                 0.000000
# 25%                               844.750000
# 50%                              7979.500000
# 75%                             35124.750000
# max                            364375.000000
#
#        Job Cards issued for non Scheduled Tribes or Scheduled Caste  \
# count                                       6.368000e+03
# mean                                        1.293401e+05
# std                                         1.283862e+05
# min                                         0.000000e+00
# 25%                                         3.729175e+04
# 50%                                         9.855200e+04
# 75%                                         1.770348e+05
# max                                         1.052879e+06
#
#        Households that demanded work  Persons who demanded work  \
# count                    6368.000000               6.368000e+03
# mean                    83431.872802               1.296206e+05
# std                     88920.617872               1.450234e+05
# min                         0.000000               0.000000e+00
# 25%                     28066.000000               3.958650e+04
# 50%                     57857.000000               8.725200e+04
# 75%                    103826.000000               1.607148e+05
# max                    845835.000000               1.408523e+06
#
#        Households that were allotted work  Persons that were allotted work  \
# count                         6368.000000                     6.368000e+03
# mean                         83240.350503                     1.291719e+05
# std                          88714.019521                     1.444940e+05
# min                              0.000000                     0.000000e+00
# 25%                          28030.000000                     3.951400e+04
# 50%                          57696.500000                     8.697550e+04
# 75%                         103629.500000                     1.600880e+05
# max                         845569.000000                     1.408250e+06
#
#        Muster Rolls filled  ...  \
# count         6.368000e+03  ...
# mean          7.493025e+04  ...
# std           1.148541e+05  ...
# min           0.000000e+00  ...
# 25%           1.264275e+04  ...
# 50%           3.515250e+04  ...
# 75%           8.843775e+04  ...
# max           1.184909e+06  ...
#
#        Works under Mahatma Gandhi National Rural Employment Guarantee Act (MGNREGA)  \
# count                                       6.314000e+03
# mean                                        1.123027e+05
# std                                         1.655803e+05
# min                                         3.000000e+00
# 25%                                         2.343900e+04
# 50%                                         6.569050e+04
# 75%                                         1.339548e+05
# max                                         2.743809e+06
#
#        Total bank accounts  Individual bank accounts  Joint bank accounts  \
# count         6.368000e+03              6.368000e+03          6368.000000
# mean          1.609514e+05              1.479356e+05         13015.837312
# std           1.812736e+05              1.753486e+05         25514.660006
# min           0.000000e+00              0.000000e+00             0.000000
# 25%           4.031075e+04              3.003175e+04           871.750000
# 50%           1.119150e+05              9.599000e+04          3989.500000
# 75%           2.150372e+05              2.011562e+05         13435.750000
# max           1.759778e+06              1.594499e+06        359968.000000
#
#        Amount disbursed to bank accounts  Post office accounts  \
# count                       6.368000e+03           6368.000000
# mean                        4.708224e+08          30585.146671
# std                         6.832622e+08          75702.228687
# min                         0.000000e+00              0.000000
# 25%                         7.213928e+07            123.750000
# 50%                         2.343758e+08           4721.500000
# 75%                         5.783000e+08          26823.500000
# max                         1.020735e+10         991749.000000
#
#        Individual post office accounts  Joint post office accounts  \
# count                      6368.000000                 6368.000000
# mean                      26833.991049                 3751.155622
# std                       72340.953638                 9972.156319
# min                           0.000000                    0.000000
# 25%                         104.000000                    1.000000
# 50%                        3698.000000                  188.000000
# 75%                       20705.750000                 2390.250000
# max                      991749.000000               158417.000000
#
#        Amount disbursed to post office accounts     YearCode
# count                              6.368000e+03  6368.000000
# mean                               4.655634e+07  2015.498587
# std                                1.625753e+08     2.871850
# min                                0.000000e+00  2011.000000
# 25%                                0.000000e+00  2013.000000
# 50%                                3.962050e+04  2015.000000
# 75%                                1.582697e+07  2018.000000
# max                                3.006468e+09  2020.000000
#
# [8 rows x 40 columns]

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.columns[:10]
# Out:
# Index(['srcyear', 'srcstatename', 'srcdistrictname',
#        'households_that_applied_for_a_job_card', 'job_cards_issued',
#        'job_cards_issued_for_scheduled_caste',
#        'job_cards_issued_for_scheduled_tribes',
#        'job_cards_issued_for_non_scheduled_tribes_or_scheduled_caste',
#        'households_that_demanded_work', 'persons_who_demanded_work'],
#       dtype='object')

# %% [markdown]
# ## 1. Identifying Districts with the Highest Employment Gaps under MGNREGA

# %%
df.columns
# Out:
# Index(['srcyear', 'srcstatename', 'srcdistrictname',
#        'households_that_applied_for_a_job_card', 'job_cards_issued',
#        'job_cards_issued_for_scheduled_caste',
#        'job_cards_issued_for_scheduled_tribes',
#        'job_cards_issued_for_non_scheduled_tribes_or_scheduled_caste',
#        'households_that_demanded_work', 'persons_who_demanded_work',
#        'households_that_were_allotted_work', 'persons_that_were_allotted_work',
#        'muster_rolls_filled',
#        'households_that_worked_under_mahatma_gandhi_national_rural_employment_guarantee_act_(mgnrega)',
#        'persons_that_worked_under_mahatma_gandhi_national_rural_employment_guarantee_act_(mgnrega)',
#        'households_that_reached_a_100_day_limit', 'persons_with_disability',
#        'non_scheduled_tribes_or_scheduled_caste_households_that_worked',
#        'total_person_days_worked_by_non_scheduled_tribes_or_scheduled_caste_persons',
#        'scheduled_caste_households_that_worked',
#        'total_person_days_worked_scheduled_caste_persons',
#        'scheduled_tribe_households_that_worked',
#        'total_person_days_worked_scheduled_tribe_persons',
#        'households_that_worked_on_land_reform_or_indira_awas_yojana',
#        'total_person_days_worked_by_women', 'total_person_days',
#        'scheduled_caste_households_that_reached_a_100_day_limit',
#        'scheduled_tribe_households_that_reached_a_100_day_limit',
#        'labour_expenditure_that_has_been_disbursed',
#        'material_expenditure_that_has_been_disbursed',
#        'labour_expenditure_both_disbursed_and_pending',
#        'material_expenditure_both_disbursed_and_pending', 'amount_sanctioned',
#        'works_under_mahatma_gandhi_national_rural_employment_guarantee_act_(mgnrega)',
#        'total_bank_accounts', 'individual_bank_accounts',
#        'joint_bank_accounts', 'amount_disbursed_to_bank_accounts',
#        'post_office_accounts', 'individual_post_office_accounts',
#        'joint_post_office_accounts',
#        'amount_disbursed_to_post_office_accounts', 'year', 'yearcode'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['srcyear',
#  'srcstatename',
#  'srcdistrictname',
#  'households_that_applied_for_a_job_card',
#  'job_cards_issued',
#  'job_cards_issued_for_scheduled_caste',
#  'job_cards_issued_for_scheduled_tribes',
#  'job_cards_issued_for_non_scheduled_tribes_or_scheduled_caste',
#  'households_that_demanded_work',
#  'persons_who_demanded_work',
#  'households_that_were_allotted_work',
#  'persons_that_were_allotted_work',
#  'muster_rolls_filled',
#  'households_that_worked_under_mahatma_gandhi_national_rural_employment_guarantee_act_(mgnrega)',
#  'persons_that_worked_under_mahatma_gandhi_national_rural_employment_guarantee_act_(mgnrega)',
#  'households_that_reached_a_100_day_limit',
#  'persons_with_disability',
#  'non_scheduled_tribes_or_scheduled_caste_households_that_worked',
#  'total_person_days_worked_by_non_scheduled_tribes_or_scheduled_caste_persons',
#  'scheduled_caste_households_that_worked',
#  'total_person_days_worked_scheduled_caste_persons',
#  'scheduled_tribe_households_that_worked',
#  'total_person_days_worked_scheduled_tribe_persons',
#  'households_that_worked_on_land_reform_or_indira_awas_yojana',
#  'total_person_days_worked_by_women',
#  'total_person_days',
#  'scheduled_caste_households_that_reached_a_100_day_limit',
#  'scheduled_tribe_households_that_reached_a_100_day_limit',
#  'labour_expenditure_that_has_been_disbursed',
#  'material_expenditure_that_has_been_disbursed',
#  'labour_expenditure_both_disbursed_and_pending',
#  'material_expenditure_both_disbursed_and_pending',
#  'amount_sanctioned',
#  'works_under_mahatma_gandhi_national_rural_employment_guarantee_act_(mgnrega)',
#  'total_bank_accounts',
#  'individual_bank_accounts',
#  'joint_bank_accounts',
#  'amount_disbursed_to_bank_accounts',
#  'post_office_accounts',
#  'individual_post_office_accounts',
#  'joint_post_office_accounts',
#  'amount_disbursed_to_post_office_accounts',
#  'year',
#  'yearcode']

# %%
df_gap = df[['srcstatename','srcdistrictname','srcyear','households_that_demanded_work','households_that_were_allotted_work']].copy()
df_gap.isnull().sum()
df_gap.dropna(inplace=True)

# %%
df_gap['employment_gap'] = df_gap['households_that_demanded_work'] - df_gap['households_that_were_allotted_work']
df_gap.head()
# Out:
#   srcstatename      srcdistrictname  srcyear  households_that_demanded_work  \
# 0  WEST BENGAL           COOCHBEHAR  2011-12                         298510
# 1  WEST BENGAL              BIRBHUM  2011-12                         469323
# 2  WEST BENGAL              BANKURA  2011-12                         327474
# 3  WEST BENGAL    24 PARGANAS SOUTH  2011-12                         197023
# 4  WEST BENGAL  24 PARGANAS (NORTH)  2011-12                         339623
#
#    households_that_were_allotted_work  employment_gap
# 0                              298387             123
# 1                              469324              -1
# 2                              327199             275
# 3                              197009              14
# 4                              339585              38

# %%
# Top 10 districts with highest employment gap
top_gap_districts = df_gap.sort_values(by='employment_gap', ascending=False)
top_gap_districts
top_gap_districts = df_gap.sort_values(by='employment_gap', ascending=False).head(10)
top_gap_districts
# Out:
#         srcstatename srcdistrictname  srcyear  households_that_demanded_work  \
# 4441  ANDHRA PRADESH          GUNTUR  2018-19                         354463
# 4442  ANDHRA PRADESH   EAST GODAVARI  2018-19                         386445
# 4440  ANDHRA PRADESH         KRISHNA  2018-19                         288793
# 4433  ANDHRA PRADESH   WEST GODAVARI  2018-19                         336432
# 4439  ANDHRA PRADESH         KURNOOL  2018-19                         396956
# 4444  ANDHRA PRADESH        CHITTOOR  2018-19                         268748
# 4445  ANDHRA PRADESH       ANANTAPUR  2018-19                         366611
# 4443  ANDHRA PRADESH        CUDDAPAH  2018-19                         252407
# 4438  ANDHRA PRADESH         NELLORE  2018-19                         285774
# 3154  ANDHRA PRADESH        PRAKASAM  2015-16                         417651
#
#       households_that_were_allotted_work  employment_gap
# 4441                              256712           97751
# 4442                              331701           54744
# 4440                              240854           47939
# 4433                              297282           39150
# 4439                              374962           21994
# 4444                              254476           14272
# 4445                              355371           11240
# 4443                              242230           10177
# 4438                              276010            9764
# 3154                              408409            9242

# %% [markdown]
# ### ✅ Conclusion:
#
# The analysis reveals that **all top 10 districts with the highest employment gaps under MGNREGA belong to the state of Andhra Pradesh**. This indicates a significant mismatch between the number of households demanding employment and those actually allotted work in the region.
#
# Such consistent under-allotment suggests possible systemic inefficiencies in MGNREGA implementation at the district level in Andhra Pradesh. Further investigation into administrative, logistical, or budgetary constraints in these districts could help bridge the employment gap and ensure more equitable job distribution under the scheme.

# %%
# Group by State and calculate total employment gap
state_gap = df_gap.groupby('srcstatename')['employment_gap'].sum().reset_index()
state_gap = state_gap.sort_values(by='employment_gap', ascending=False)
# heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(state_gap.set_index('srcstatename'), annot=True, fmt=".0f", cmap='OrRd', linewidths=0.5, linecolor='gray')

plt.title('Total Employment Gap by State (MGNREGA)')
plt.ylabel('State')
plt.xlabel('Employment Gap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.Investigate the participation of women in MGNREGA by analyzing total person-days worked by women across states and years.

# %%
df_gender = df[['srcstatename', 'srcyear', 'total_person_days_worked_by_women']].copy()
df_gender.dropna(inplace=True)
total_by_state = df_gender.groupby(['srcstatename','srcyear'])['total_person_days_worked_by_women'].sum().reset_index()
total_by_state = total_by_state.sort_values(by=['srcstatename','srcyear'])
total_by_state
# Out:
#             srcstatename  srcyear  total_person_days_worked_by_women
# 0    ANDAMAN AND NICOBAR  2011-12                             384593
# 1    ANDAMAN AND NICOBAR  2012-13                             298349
# 2    ANDAMAN AND NICOBAR  2013-14                             379322
# 3    ANDAMAN AND NICOBAR  2014-15                             278639
# 4    ANDAMAN AND NICOBAR  2015-16                             140007
# ..                   ...      ...                                ...
# 325          WEST BENGAL  2016-17                          105003151
# 326          WEST BENGAL  2017-18                          125732891
# 327          WEST BENGAL  2018-19                          136663227
# 328          WEST BENGAL  2019-20                          111641019
# 329          WEST BENGAL  2020-21                          165043438
#
# [330 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

for state in total_by_state['srcstatename'].unique():
    state_data = total_by_state[total_by_state['srcstatename'] == state]
    plt.plot(state_data['srcyear'], state_data['total_person_days_worked_by_women'], label=state)

plt.title('Women Participation in MGNREGA (Person-Days Worked)', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Person-Days by Women in Millions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Total participation by state (all years combined)
top_states = df_gender.groupby('srcstatename')['total_person_days_worked_by_women'].sum().reset_index()
top_states = top_states.sort_values(by='total_person_days_worked_by_women', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(data=top_states.head(10), y='srcstatename', x='total_person_days_worked_by_women', palette='magma')
plt.title('Top 10 States by Women Participation in MGNREGA (All Years)', fontsize=13)
plt.xlabel('Total Person-Days Worked by Women in millions')
plt.ylabel('State')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10724\2216884543.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_states.head(10), y='srcstatename', x='total_person_days_worked_by_women', palette='magma')

# %% [markdown]
# ## This section analyzes the **participation of women** in the MGNREGA scheme using total person-days worked across states and years.
#
# - 📊 The **line plot** shows year-wise trends of women’s employment under MGNREGA across Indian states.
# - 🥇 The **bar chart** ranks the top 10 states by their total women person-days worked — states like **Tamil Nadu, Andhra Pradesh, and Kerala** often top the list.
